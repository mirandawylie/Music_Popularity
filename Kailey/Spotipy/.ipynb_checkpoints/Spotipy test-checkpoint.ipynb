# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
from config import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET

# %%
#Set up Spotify credentials
client_credentials_manager = SpotifyClientCredentials(SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Set up Hot 100 csv
hot100 = pd.read_csv('charts.csv')
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 1  2021-06-12     2             Good 4 U
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                      artist  last-week  peak-rank  \
# 0                                       BTS        1.0          1
# 1                            Olivia Rodrigo        2.0          1
# 2                 Dua Lipa Featuring DaBaby        4.0          2
# 3  Silk Sonic (Bruno Mars & Anderson .Paak)        5.0          1
# 4                The Weeknd & Ariana Grande        7.0          1
#
#    weeks-on-board
# 0               2
# 1               3
# 2              35
# 3              13
# 4              25

# %%
#Clean Hot 100 dataframe
hot100.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         31971
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
hot100 = hot100.drop(columns = ['last-week'])
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 1  2021-06-12     2             Good 4 U
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                      artist  peak-rank  weeks-on-board
# 0                                       BTS          1               2
# 1                            Olivia Rodrigo          1               3
# 2                 Dua Lipa Featuring DaBaby          2              35
# 3  Silk Sonic (Bruno Mars & Anderson .Paak)          1              13
# 4                The Weeknd & Ariana Grande          1              25

# %%
hot100.value_counts()
# Out:
# date        rank  song                                                              artist                     peak-rank  weeks-on-board
# 2021-06-12  100   Botella Tras Botella                                              Gera MX + Christian Nodal  60         4                 1
# 1979-08-04  55    Saturdaynight                                                     Herman Brood               55         4                 1
# 1979-07-21  37    The Devil Went Down To Georgia                                    The Charlie Daniels Band   37         5                 1
#             38    Just When I Needed You Most                                       Randy VanWarmer            4          18                1
#             39    If I Said You Have A Beautiful Body Would You Hold It Against Me  Bellamy Brothers           39         9                 1
#                                                                                                                                            ..
# 2000-07-01  73    Whatever                                                          Ideal Featuring Lil' Mo    67         4                 1
#             74    It Must Be Love                                                   Alan Jackson               74         2                 1
#             75    With Arms Wide Open                                               Creed                      68         8                 1
#             76    No More                                                           Ruff Endz                  76         1                 1
# 1958-08-04  1     Poor Little Fool                                                  Ricky Nelson               1          1                 1
# Length: 327987, dtype: int64

# %%
hot100.dtypes
# Out:
# date              object
# rank               int64
# song              object
# artist            object
# peak-rank          int64
# weeks-on-board     int64
# dtype: object

# %%
hot100["date"] = pd.to_datetime(hot100["date"])
hot100.dtypes
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# peak-rank                  int64
# weeks-on-board             int64
# dtype: object

# %%
hot100 = hot100.sort_values(by = 'date', ascending = False)
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 11 2021-06-12    12              Traitor
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                       artist  peak-rank  weeks-on-board
# 0                                        BTS          1               2
# 11                            Olivia Rodrigo          9               2
# 2                  Dua Lipa Featuring DaBaby          2              35
# 3   Silk Sonic (Bruno Mars & Anderson .Paak)          1              13
# 4                 The Weeknd & Ariana Grande          1              25

# %%
selecthot100 = hot100.loc[(hot100['date'] >= '2020-01-01') & (hot100['date'] <='2020-12-31')]
selecthot100 = selecthot1
# Out:
# date        rank  song                             artist                        peak-rank  weeks-on-board
# 2020-12-26  100   Beautiful Trip                   Kid Cudi                      100        1                 1
# 2020-05-02  46    Stupid Love                      Lady Gaga                     5          8                 1
#             28    Heartless                        The Weeknd                    1          22                1
#             29    Heart On Ice                     Rod Wave                      25         24                1
#             30    More Hearts Than Mine            Ingrid Andress                30         17                1
#                                                                                                              ..
# 2020-08-29  69    Bang!                            AJR                           69         7                 1
#             70    God Whispered Your Name          Keith Urban                   60         18                1
#             71    24                               Money Man Featuring Lil Baby  71         1                 1
#             72    Toosie Slide                     Drake                         1          20                1
# 2020-01-04  1     All I Want For Christmas Is You  Mariah Carey                  1          37                1
# Length: 5200, dtype: int64

# %%
def searchSongs(title, artist):
    cleaned_artist = artist.replace(" Featuring", "")
    results = sp.search(q=f'track:{title} artist:{cleaned_artist}')
    top_result = results['tracks']['items'][0]
    song_dict = {'song_title': top_result['name'],
                'song_artist': top_result['artists'][0]['name'],
                'song_id': top_result['id'],
                'popularity': top_result['popularity']}
    return song_dict

# %%
#define songs for search
song_artist = pd.DataFrame(data = selecthot100, columns = ['song', 'artist'])

# %%
#Create song dicts
hot_song_dicts = [searchSongs(item['song'], item['artist']) for idx, item in song_artist.iterrows()]
hot_song_dicts
# Out:
# [{'song_title': 'Underneath the Tree',
#   'song_artist': 'Kelly Clarkson',
#   'song_id': '3YZE5qDV7u1ZD1gZc47ZeR',
#   'popularity': 48},
#  {'song_title': 'Jingle Bell Rock',
#   'song_artist': 'Bobby Helms',
#   'song_id': '7vQbuQcyTflfCIOu3Uzzya',
#   'popularity': 55},
#  {'song_title': 'A Holly Jolly Christmas - Single Version',
#   'song_artist': 'Burl Ives',
#   'song_id': '77khP2fIVhSW23NwxrRluh',
#   'popularity': 48},
#  {'song_title': "It's the Most Wonderful Time of the Year",
#   'song_artist': 'Andy Williams',
#   'song_id': '5hslUAKq9I9CG2bAulFkHN',
#   'popularity': 53},
#  {'song_title': 'Feliz Navidad',
#   'song_artist': 'José Feliciano',
#   'song_id': '0oPdaY4dXtc3ZsaG17V972',
#   'popularity': 48},
#  {'song_title': 'Mood (feat. iann dior)',
#   'song_artist': '24kGoldn',
#   'song_id': '4jPy3l0RUwlUI9T5XHBW2m',
#   'popularity': 90},
#  {'song_title': 'Let It Snow! Let It Snow! Let It Snow!',
#   'song_artist': 'Dean Martin',
#   'song_id': '2uFaJJtFpPDc5Pa95XzTvg',
#   'popularity': 52},
#  {'song_title': "Rockin' Around The Christmas Tree",
#   'song_artist': 'Brenda Lee',
#   'song_id': '2EjXfH91m7f8HiJN1yQg97',
#   'popularity': 56},
#  {'song_title': 'Last Christmas',
#   'song_artist': 'Wham!',
#   'song_id': '2FRnf9qhLbvw8fu4IBXx78',
#   'popularity': 62},
#  {'song_title': 'Go Crazy',
#   'song_artist': 'Chris Brown',
#   'song_id': '1IIKrJVP1C9N7iPtG6eOsK',
#   'popularity': 81}]

# %%
def getTrackFeatures(song_id):
    meta = sp.track(song_id)
    features = sp.audio_features(song_id)
    
    track= {
        # Meta data
        "name": meta['name'],
        "album": meta['album']['name'],
        "artist": meta['album']['artists'][0]['name'],
        "release_date": meta['album']['release_date'],
        "length": meta['duration_ms'],
        "popularity": meta['popularity'],

        # features
        "acousticness": features[0]['acousticness'],
        "danceability": features[0]['danceability'],
        "energy": features[0]['energy'],
        "instrumentalness": features[0]['instrumentalness'],
        "liveness": features[0]['liveness'],
        "loudness": features[0]['loudness'],
        "speechiness": features[0]['speechiness'],
        "tempo": features[0]['tempo'],
        "time_signature": features[0]['time_signature'],

    }
    
    return track

# %%
# Access song_id to get the rest of the features
hot_song_features = [getTrackFeatures(song_dict['song_id']) for song_dict in hot_song_dicts]
hot_song_features
# Out:
# [{'name': 'Underneath the Tree',
#   'album': 'Wrapped In Red',
#   'artist': 'Kelly Clarkson',
#   'release_date': '2013-10-29',
#   'length': 229640,
#   'popularity': 48,
#   'acousticness': 0.00128,
#   'danceability': 0.509,
#   'energy': 0.812,
#   'instrumentalness': 1.99e-05,
#   'liveness': 0.214,
#   'loudness': -5.439,
#   'speechiness': 0.0537,
#   'tempo': 159.878,
#   'time_signature': 4},
#  {'name': 'Jingle Bell Rock',
#   'album': 'Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)',
#   'artist': 'Bobby Helms',
#   'release_date': '1957-12-02',
#   'length': 130973,
#   'popularity': 55,
#   'acousticness': 0.643,
#   'danceability': 0.754,
#   'energy': 0.424,
#   'instrumentalness': 0,
#   'liveness': 0.0652,
#   'loudness': -8.463,
#   'speechiness': 0.0363,
#   'tempo': 119.705,
#   'time_signature': 4},
#  {'name': 'A Holly Jolly Christmas - Single Version',
#   'album': 'Have A Holly Jolly Christmas',
#   'artist': 'Burl Ives',
#   'release_date': '1965-01-01',
#   'length': 135533,
#   'popularity': 48,
#   'acousticness': 0.579,
#   'danceability': 0.683,
#   'energy': 0.375,
#   'instrumentalness': 0,
#   'liveness': 0.076,
#   'loudness': -13.056,
#   'speechiness': 0.0303,
#   'tempo': 140.467,
#   'time_signature': 4},
#  {'name': "It's the Most Wonderful Time of the Year",
#   'album': 'The Andy Williams Christmas Album',
#   'artist': 'Andy Williams',
#   'release_date': '1963-11-24',
#   'length': 151933,
#   'popularity': 53,
#   'acousticness': 0.766,
#   'danceability': 0.24,
#   'energy': 0.598,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'loudness': -8.435,
#   'speechiness': 0.0369,
#   'tempo': 201.629,
#   'time_signature': 3},
#  {'name': 'Feliz Navidad',
#   'album': 'Feliz Navidad',
#   'artist': 'José Feliciano',
#   'release_date': '2002-09-24',
#   'length': 182066,
#   'popularity': 48,
#   'acousticness': 0.55,
#   'danceability': 0.513,
#   'energy': 0.831,
#   'instrumentalness': 0,
#   'liveness': 0.336,
#   'loudness': -9.004,
#   'speechiness': 0.0383,
#   'tempo': 148.837,
#   'time_signature': 4},
#  {'name': 'Mood (feat. iann dior)',
#   'album': 'El Dorado',
#   'artist': '24kGoldn',
#   'release_date': '2021-03-26',
#   'length': 140533,
#   'popularity': 90,
#   'acousticness': 0.174,
#   'danceability': 0.701,
#   'energy': 0.716,
#   'instrumentalness': 0,
#   'liveness': 0.324,
#   'loudness': -3.671,
#   'speechiness': 0.0361,
#   'tempo': 91.007,
#   'time_signature': 4},
#  {'name': 'Let It Snow! Let It Snow! Let It Snow!',
#   'album': 'A Winter Romance',
#   'artist': 'Dean Martin',
#   'release_date': '1959-01-01',
#   'length': 117146,
#   'popularity': 52,
#   'acousticness': 0.912,
#   'danceability': 0.451,
#   'energy': 0.24,
#   'instrumentalness': 2.45e-06,
#   'liveness': 0.175,
#   'loudness': -14.014,
#   'speechiness': 0.0351,
#   'tempo': 134.009,
#   'time_signature': 4},
#  {'name': "Rockin' Around The Christmas Tree",
#   'album': 'Merry Christmas From Brenda Lee',
#   'artist': 'Brenda Lee',
#   'release_date': '1964-10-19',
#   'length': 126266,
#   'popularity': 56,
#   'acousticness': 0.614,
#   'danceability': 0.589,
#   'energy': 0.472,
#   'instrumentalness': 0,
#   'liveness': 0.505,
#   'loudness': -8.749,
#   'speechiness': 0.0502,
#   'tempo': 67.196,
#   'time_signature': 4},
#  {'name': 'Last Christmas',
#   'album': 'LAST CHRISTMAS',
#   'artist': 'Wham!',
#   'release_date': '1984-11-29',
#   'length': 262960,
#   'popularity': 62,
#   'acousticness': 0.189,
#   'danceability': 0.735,
#   'energy': 0.478,
#   'instrumentalness': 2.48e-06,
#   'liveness': 0.355,
#   'loudness': -12.472,
#   'speechiness': 0.0293,
#   'tempo': 107.682,
#   'time_signature': 4},
#  {'name': 'Go Crazy',
#   'album': 'Slime & B',
#   'artist': 'Chris Brown',
#   'release_date': '2020-05-08',
#   'length': 176960,
#   'popularity': 81,
#   'acousticness': 0.316,
#   'danceability': 0.755,
#   'energy': 0.578,
#   'instrumentalness': 0,
#   'liveness': 0.25,
#   'loudness': -8.932,
#   'speechiness': 0.145,
#   'tempo': 94.148,
#   'time_signature': 4}]

# %%
cleaned_hot_songs = pd.DataFrame(data = hot_song_features)
cleaned_hot_songs
# Out:
#                                        name  \
# 0                       Underneath the Tree
# 1                          Jingle Bell Rock
# 2  A Holly Jolly Christmas - Single Version
# 3  It's the Most Wonderful Time of the Year
# 4                             Feliz Navidad
# 5                    Mood (feat. iann dior)
# 6    Let It Snow! Let It Snow! Let It Snow!
# 7         Rockin' Around The Christmas Tree
# 8                            Last Christmas
# 9                                  Go Crazy
#
#                                                album          artist  \
# 0                                     Wrapped In Red  Kelly Clarkson
# 1  Jingle Bell Rock/Captain Santa Claus (And His ...     Bobby Helms
# 2                       Have A Holly Jolly Christmas       Burl Ives
# 3                  The Andy Williams Christmas Album   Andy Williams
# 4                                      Feliz Navidad  José Feliciano
# 5                                          El Dorado        24kGoldn
# 6                                   A Winter Romance     Dean Martin
# 7                    Merry Christmas From Brenda Lee      Brenda Lee
# 8                                     LAST CHRISTMAS           Wham!
# 9                                          Slime & B     Chris Brown
#
#   release_date  length  popularity  acousticness  danceability  energy  \
# 0   2013-10-29  229640          48       0.00128         0.509   0.812
# 1   1957-12-02  130973          55       0.64300         0.754   0.424
# 2   1965-01-01  135533          48       0.57900         0.683   0.375
# 3   1963-11-24  151933          53       0.76600         0.240   0.598
# 4   2002-09-24  182066          48       0.55000         0.513   0.831
# 5   2021-03-26  140533          90       0.17400         0.701   0.716
# 6   1959-01-01  117146          52       0.91200         0.451   0.240
# 7   1964-10-19  126266          56       0.61400         0.589   0.472
# 8   1984-11-29  262960          62       0.18900         0.735   0.478
# 9   2020-05-08  176960          81       0.31600         0.755   0.578
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.000020    0.2140    -5.439       0.0537  159.878               4
# 1          0.000000    0.0652    -8.463       0.0363  119.705               4
# 2          0.000000    0.0760   -13.056       0.0303  140.467               4
# 3          0.000000    0.1170    -8.435       0.0369  201.629               3
# 4          0.000000    0.3360    -9.004       0.0383  148.837               4
# 5          0.000000    0.3240    -3.671       0.0361   91.007               4
# 6          0.000002    0.1750   -14.014       0.0351  134.009               4
# 7          0.000000    0.5050    -8.749       0.0502   67.196               4
# 8          0.000002    0.3550   -12.472       0.0293  107.682               4
# 9          0.000000    0.2500    -8.932       0.1450   94.148               4

# %%
cleaned_hot_songs.to_csv(path_or_buf = r"Song Features/test.csv", index=False)
