# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
from config import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET

# %%
#Set up Spotify credentials
client_credentials_manager = SpotifyClientCredentials(SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Set up Hot 100 csv
hot100 = pd.read_csv('charts.csv')
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 1  2021-06-12     2             Good 4 U
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                      artist  last-week  peak-rank  \
# 0                                       BTS        1.0          1
# 1                            Olivia Rodrigo        2.0          1
# 2                 Dua Lipa Featuring DaBaby        4.0          2
# 3  Silk Sonic (Bruno Mars & Anderson .Paak)        5.0          1
# 4                The Weeknd & Ariana Grande        7.0          1
#
#    weeks-on-board
# 0               2
# 1               3
# 2              35
# 3              13
# 4              25

# %%
#Clean Hot 100 dataframe
hot100.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         31971
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
hot100 = hot100.drop(columns = ['last-week'])
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 1  2021-06-12     2             Good 4 U
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                      artist  peak-rank  weeks-on-board
# 0                                       BTS          1               2
# 1                            Olivia Rodrigo          1               3
# 2                 Dua Lipa Featuring DaBaby          2              35
# 3  Silk Sonic (Bruno Mars & Anderson .Paak)          1              13
# 4                The Weeknd & Ariana Grande          1              25

# %%
hot100.value_counts()
# Out:
# date        rank  song                                                              artist                     peak-rank  weeks-on-board
# 2021-06-12  100   Botella Tras Botella                                              Gera MX + Christian Nodal  60         4                 1
# 1979-08-04  55    Saturdaynight                                                     Herman Brood               55         4                 1
# 1979-07-21  37    The Devil Went Down To Georgia                                    The Charlie Daniels Band   37         5                 1
#             38    Just When I Needed You Most                                       Randy VanWarmer            4          18                1
#             39    If I Said You Have A Beautiful Body Would You Hold It Against Me  Bellamy Brothers           39         9                 1
#                                                                                                                                            ..
# 2000-07-01  73    Whatever                                                          Ideal Featuring Lil' Mo    67         4                 1
#             74    It Must Be Love                                                   Alan Jackson               74         2                 1
#             75    With Arms Wide Open                                               Creed                      68         8                 1
#             76    No More                                                           Ruff Endz                  76         1                 1
# 1958-08-04  1     Poor Little Fool                                                  Ricky Nelson               1          1                 1
# Length: 327987, dtype: int64

# %%
hot100.dtypes
# Out:
# date              object
# rank               int64
# song              object
# artist            object
# peak-rank          int64
# weeks-on-board     int64
# dtype: object

# %%
hot100["date"] = pd.to_datetime(hot100["date"])
hot100.dtypes
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# peak-rank                  int64
# weeks-on-board             int64
# dtype: object

# %%
hot100 = hot100.sort_values(by = 'date', ascending = False)
hot100.head()
# Out:
#          date  rank         song                 artist  peak-rank  \
# 0  2021-06-12     1       Butter                    BTS          1
# 64 2021-06-12    65        amari                J. Cole          5
# 75 2021-06-12    76  What's Next                  Drake          1
# 73 2021-06-12    74    4 Da Gang  42 Dugg & Roddy Ricch         67
# 72 2021-06-12    73    Quicksand                 Morray         65
#
#     weeks-on-board
# 0                2
# 64               3
# 75              13
# 73               9
# 72              17

# %%
selecthot100 = hot100.loc[(hot100['date'] >= '2020-01-01') & (hot100['date'] <='2020-12-31')]
selecthot100 = selecthot100.head(10)

# %%
def searchSongs(title, artist):
    cleaned_artist = artist.replace(" Featuring", "")
    results = sp.search(q=f'track:{title} artist:{cleaned_artist}')
    top_result = results['tracks']['items'][0]
    song_dict = {'song_title': top_result['name'],
                'song_artist': top_result['artists'][0]['name'],
                'song_id': top_result['id'],
                'popularity': top_result['popularity']}
    return song_dict

# %%
#define songs for search
song_artist = pd.DataFrame(data = selecthot100, columns = ['song', 'artist'])

# %%
#Create song dicts
hot_song_dicts = [searchSongs(item['song'], item['artist']) for idx, item in song_artist.iterrows()]
hot_song_dicts
# Out:
# [{'song_title': 'Another Day',
#   'song_artist': 'Kid Cudi',
#   'song_id': '6myUpr3GDR80Dg3zqNTmmG',
#   'popularity': 64},
#  {'song_title': 'Big, Big Plans',
#   'song_artist': 'Chris Lane',
#   'song_id': '7yNJCsUH3tXlpQiHSsAc5l',
#   'popularity': 71},
#  {'song_title': 'Starting Over',
#   'song_artist': 'Chris Stapleton',
#   'song_id': '3K07bGe8iljQ3mOKArHLDo',
#   'popularity': 70},
#  {'song_title': 'cowboy like me',
#   'song_artist': 'Taylor Swift',
#   'song_id': '1XjHRolIXL2M1EEOUsGGR4',
#   'popularity': 64},
#  {'song_title': 'I Should Probably Go To Bed',
#   'song_artist': 'Dan + Shay',
#   'song_id': '5ovVcYo2MvjVydFwFyaaqy',
#   'popularity': 73},
#  {'song_title': 'Here Comes Santa Claus (Right Down Santa Claus Lane) - 1947 Version',
#   'song_artist': 'Gene Autry',
#   'song_id': '25leEEaz1gIpp7o21Fqyjo',
#   'popularity': 42},
#  {'song_title': 'long story short',
#   'song_artist': 'Taylor Swift',
#   'song_id': '2o2sgVJIgFXk8GQjWTgI6U',
#   'popularity': 66},
#  {'song_title': 'Way Out (feat. Big Sean)',
#   'song_artist': 'Jack Harlow',
#   'song_id': '6rLi6PyWXu1rPlShuIZpj6',
#   'popularity': 73},
#  {'song_title': 'dorothea',
#   'song_artist': 'Taylor Swift',
#   'song_id': '670fUmXf4KQekzbEgaXyPA',
#   'popularity': 64},
#  {'song_title': 'Diamonds',
#   'song_artist': 'Sam Smith',
#   'song_id': '5hvwx5i67IwnCkjl9VHkNv',
#   'popularity': 77}]

# %%
def getTrackFeatures(song_id):
    meta = sp.track(song_id)
    features = sp.audio_features(song_id)
    
    track= {
        # Meta data
        "name": meta['name'],
        "album": meta['album']['name'],
        "artist": meta['album']['artists'][0]['name'],
        "release_date": meta['album']['release_date'],
        "length": meta['duration_ms'],
        "popularity": meta['popularity'],

        # features
        "acousticness": features[0]['acousticness'],
        "danceability": features[0]['danceability'],
        "energy": features[0]['energy'],
        "instrumentalness": features[0]['instrumentalness'],
        "liveness": features[0]['liveness'],
        "loudness": features[0]['loudness'],
        "speechiness": features[0]['speechiness'],
        "tempo": features[0]['tempo'],
        "time_signature": features[0]['time_signature'],

    }
    
    return track

# %%
# Access song_id to get the rest of the features
hot_song_features = [getTrackFeatures(song_dict['song_id']) for song_dict in hot_song_dicts]
hot_song_features
# Out:
# [{'name': 'Another Day',
#   'album': 'Man On The Moon III: The Chosen',
#   'artist': 'Kid Cudi',
#   'release_date': '2020-12-11',
#   'length': 199786,
#   'popularity': 64,
#   'acousticness': 0.556,
#   'danceability': 0.646,
#   'energy': 0.758,
#   'instrumentalness': 0.00316,
#   'liveness': 0.335,
#   'loudness': -7.75,
#   'speechiness': 0.0708,
#   'tempo': 172.995,
#   'time_signature': 4},
#  {'name': 'Big, Big Plans',
#   'album': 'Big, Big Plans',
#   'artist': 'Chris Lane',
#   'release_date': '2019-06-28',
#   'length': 187306,
#   'popularity': 71,
#   'acousticness': 0.076,
#   'danceability': 0.574,
#   'energy': 0.58,
#   'instrumentalness': 0,
#   'liveness': 0.12,
#   'loudness': -6.091,
#   'speechiness': 0.0278,
#   'tempo': 149.974,
#   'time_signature': 4},
#  {'name': 'Starting Over',
#   'album': 'Starting Over',
#   'artist': 'Chris Stapleton',
#   'release_date': '2020-11-13',
#   'length': 240413,
#   'popularity': 70,
#   'acousticness': 0.452,
#   'danceability': 0.638,
#   'energy': 0.538,
#   'instrumentalness': 0.000415,
#   'liveness': 0.0695,
#   'loudness': -8.445,
#   'speechiness': 0.0315,
#   'tempo': 89.124,
#   'time_signature': 4},
#  {'name': 'cowboy like me',
#   'album': 'evermore',
#   'artist': 'Taylor Swift',
#   'release_date': '2020-12-11',
#   'length': 275040,
#   'popularity': 64,
#   'acousticness': 0.768,
#   'danceability': 0.604,
#   'energy': 0.517,
#   'instrumentalness': 0.000155,
#   'liveness': 0.123,
#   'loudness': -9.014,
#   'speechiness': 0.0347,
#   'tempo': 127.967,
#   'time_signature': 4},
#  {'name': 'I Should Probably Go To Bed',
#   'album': 'I Should Probably Go To Bed',
#   'artist': 'Dan + Shay',
#   'release_date': '2020-07-31',
#   'length': 171826,
#   'popularity': 73,
#   'acousticness': 0.634,
#   'danceability': 0.721,
#   'energy': 0.277,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'loudness': -7.128,
#   'speechiness': 0.0365,
#   'tempo': 131.935,
#   'time_signature': 4},
#  {'name': 'Here Comes Santa Claus (Right Down Santa Claus Lane) - 1947 Version',
#   'album': 'Rudolph The Red Nosed Reindeer And Other Christmas Classics',
#   'artist': 'Gene Autry',
#   'release_date': '1947',
#   'length': 150266,
#   'popularity': 42,
#   'acousticness': 0.799,
#   'danceability': 0.834,
#   'energy': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.275,
#   'loudness': -11.99,
#   'speechiness': 0.0358,
#   'tempo': 96.628,
#   'time_signature': 4},
#  {'name': 'long story short',
#   'album': 'evermore',
#   'artist': 'Taylor Swift',
#   'release_date': '2020-12-11',
#   'length': 215920,
#   'popularity': 66,
#   'acousticness': 0.66,
#   'danceability': 0.546,
#   'energy': 0.73,
#   'instrumentalness': 0.179,
#   'liveness': 0.0972,
#   'loudness': -7.704,
#   'speechiness': 0.0417,
#   'tempo': 157.895,
#   'time_signature': 4},
#  {'name': 'Way Out (feat. Big Sean)',
#   'album': 'Way Out (feat. Big Sean)',
#   'artist': 'Jack Harlow',
#   'release_date': '2020-12-09',
#   'length': 168906,
#   'popularity': 73,
#   'acousticness': 0.114,
#   'danceability': 0.945,
#   'energy': 0.582,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'loudness': -8.357,
#   'speechiness': 0.0719,
#   'tempo': 108.025,
#   'time_signature': 4},
#  {'name': 'dorothea',
#   'album': 'evermore',
#   'artist': 'Taylor Swift',
#   'release_date': '2020-12-11',
#   'length': 225880,
#   'popularity': 64,
#   'acousticness': 0.696,
#   'danceability': 0.605,
#   'energy': 0.488,
#   'instrumentalness': 0,
#   'liveness': 0.129,
#   'loudness': -8.322,
#   'speechiness': 0.0264,
#   'tempo': 119.966,
#   'time_signature': 4},
#  {'name': 'Diamonds',
#   'album': 'Diamonds',
#   'artist': 'Sam Smith',
#   'release_date': '2020-09-17',
#   'length': 213869,
#   'popularity': 77,
#   'acousticness': 0.154,
#   'danceability': 0.653,
#   'energy': 0.667,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'loudness': -6.764,
#   'speechiness': 0.0423,
#   'tempo': 104.181,
#   'time_signature': 4}]

# %%
cleaned_hot_songs = pd.DataFrame(data = hot_song_features)
cleaned_hot_songs
# Out:
#                                                 name  \
# 0                                        Another Day
# 1                                     Big, Big Plans
# 2                                      Starting Over
# 3                                     cowboy like me
# 4                        I Should Probably Go To Bed
# 5  Here Comes Santa Claus (Right Down Santa Claus...
# 6                                   long story short
# 7                           Way Out (feat. Big Sean)
# 8                                           dorothea
# 9                                           Diamonds
#
#                                                album           artist  \
# 0                    Man On The Moon III: The Chosen         Kid Cudi
# 1                                     Big, Big Plans       Chris Lane
# 2                                      Starting Over  Chris Stapleton
# 3                                           evermore     Taylor Swift
# 4                        I Should Probably Go To Bed       Dan + Shay
# 5  Rudolph The Red Nosed Reindeer And Other Chris...       Gene Autry
# 6                                           evermore     Taylor Swift
# 7                           Way Out (feat. Big Sean)      Jack Harlow
# 8                                           evermore     Taylor Swift
# 9                                           Diamonds        Sam Smith
#
#   release_date  length  popularity  acousticness  danceability  energy  \
# 0   2020-12-11  199786          64         0.556         0.646   0.758
# 1   2019-06-28  187306          71         0.076         0.574   0.580
# 2   2020-11-13  240413          70         0.452         0.638   0.538
# 3   2020-12-11  275040          64         0.768         0.604   0.517
# 4   2020-07-31  171826          73         0.634         0.721   0.277
# 5         1947  150266          42         0.799         0.834   0.371
# 6   2020-12-11  215920          66         0.660         0.546   0.730
# 7   2020-12-09  168906          73         0.114         0.945   0.582
# 8   2020-12-11  225880          64         0.696         0.605   0.488
# 9   2020-09-17  213869          77         0.154         0.653   0.667
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.003160    0.3350    -7.750       0.0708  172.995               4
# 1          0.000000    0.1200    -6.091       0.0278  149.974               4
# 2          0.000415    0.0695    -8.445       0.0315   89.124               4
# 3          0.000155    0.1230    -9.014       0.0347  127.967               4
# 4          0.000000    0.1120    -7.128       0.0365  131.935               4
# 5          0.000000    0.2750   -11.990       0.0358   96.628               4
# 6          0.179000    0.0972    -7.704       0.0417  157.895               4
# 7          0.000000    0.1030    -8.357       0.0719  108.025               4
# 8          0.000000    0.1290    -8.322       0.0264  119.966               4
# 9          0.000000    0.1070    -6.764       0.0423  104.181               4

# %%
cleaned_hot_songs.to_csv(path_or_buf = r"Song Features/test.csv", index=False)
