# %%
import json
import pandas as pd
import numpy as np

# %%
# read in spotify API data CSV

data = pd.read_csv('group_data.csv', error_bad_lines=False)
data
# Out:
# b'Skipping line 3520: expected 16 fields, saw 17\nSkipping line 3613: expected 16 fields, saw 17\nSkipping line 3718: expected 16 fields, saw 17\nSkipping line 3879: expected 16 fields, saw 17\nSkipping line 3983: expected 16 fields, saw 17\nSkipping line 4083: expected 16 fields, saw 17\nSkipping line 4187: expected 16 fields, saw 17\nSkipping line 4297: expected 16 fields, saw 17\nSkipping line 4399: expected 16 fields, saw 17\nSkipping line 4492: expected 16 fields, saw 17\nSkipping line 4576: expected 16 fields, saw 17\nSkipping line 4699: expected 16 fields, saw 17\nSkipping line 4777: expected 16 fields, saw 17\nSkipping line 4872: expected 16 fields, saw 17\nSkipping line 4985: expected 16 fields, saw 17\nSkipping line 5098: expected 16 fields, saw 17\nSkipping line 5199: expected 16 fields, saw 17\nSkipping line 5290: expected 16 fields, saw 17\nSkipping line 5349: expected 16 fields, saw 17\nSkipping line 5494: expected 16 fields, saw 17\n'
# ...

# %%
data.isna().sum()
# Out:
# song                 109
# artist               109
# release_date         109
# popularity           109
# acousticness         109
# danceability         109
# energy               109
# instrumentalness     109
# liveness             109
# loudness             109
# speechiness          109
# tempo                109
# popular_date           0
# ranking                0
# weeks_on_board         0
# genres              3121
# dtype: int64

# %%
hip_hop = data[data['genres'].str.contains("hip hop", na=False)]
hip_hop
# Out:
#                                        song        artist release_date  \
# 2         BEST ON EARTH (feat. BIA) - Bonus          Russ   2020-01-31
# 10                                    SUGAR  BROCKHAMPTON   2019-08-23
# 21     TOES (feat. Lil Baby & Moneybagg Yo)        DaBaby   2019-09-27
# 24             Jerry Sprunger (with T-Pain)    Tory Lanez   2019-11-15
# 25                                  Camelot    NLE Choppa   2019-09-13
# ...                                     ...           ...          ...
# 52494                         Run This Town         JAY-Z   2009-09-08
# 52496                     Hell Breaks Loose        Eminem   2009-05-15
# 52498             Tie Me Down (feat. Ray J)      New Boyz   2009-09-15
# 52502                           Gangsta Luv    Snoop Dogg   2009-01-01
# 52503                            Baby By Me       50 Cent   2009-01-01
#
#        popularity  acousticness  danceability  energy  instrumentalness  \
# ...

# %%
hip_hop.loc[hip_hop['genres'].str.contains('hip hop'), 'genres'] = 'hip hop'
hip_hop
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                        song        artist release_date  \
# 2         BEST ON EARTH (feat. BIA) - Bonus          Russ   2020-01-31
# 10                                    SUGAR  BROCKHAMPTON   2019-08-23
# 21     TOES (feat. Lil Baby & Moneybagg Yo)        DaBaby   2019-09-27
# 24             Jerry Sprunger (with T-Pain)    Tory Lanez   2019-11-15
# 25                                  Camelot    NLE Choppa   2019-09-13
# ...                                     ...           ...          ...
# ...

# %%
pop = data[data['genres'].str.contains("pop", na=False)]
pop
# Out:
#                                                     song           artist  \
# 1                              RITMO (Bad Boys For Life)  Black Eyed Peas
# 2                      BEST ON EARTH (feat. BIA) - Bonus             Russ
# 5                                                  Slide           H.E.R.
# 8                                        Make Me Want To     Jimmie Allen
# 11     Playing Games (with Bryson Tiller) - Extended ...    Summer Walker
# ...                                                  ...              ...
# 52499               Evacuate The Dancefloor - Radio Edit          Cascada
# 52500                              Live Like We're Dying       Kris Allen
# 52501                           Say Aah (feat. Fabolous)       Trey Songz
# 52502                                        Gangsta Luv       Snoop Dogg
# 52503                                         Baby By Me          50 Cent
#
#       release_date  popularity  acousticness  danceability  energy  \
# ...

# %%
pop.loc[pop['genres'].str.contains('pop'), 'genres'] = 'pop'
pop
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                                     song           artist  \
# 1                              RITMO (Bad Boys For Life)  Black Eyed Peas
# 2                      BEST ON EARTH (feat. BIA) - Bonus             Russ
# 5                                                  Slide           H.E.R.
# 8                                        Make Me Want To     Jimmie Allen
# 11     Playing Games (with Bryson Tiller) - Extended ...    Summer Walker
# ...                                                  ...              ...
# ...

# %%
# rap = data[data['genres'].str.contains("rap", na=False)]
# rap

# %%
country = data[data['genres'].str.contains("country", na=False)]
country
# Out:
#                                  song            artist release_date  \
# 4          I Wish Grandpas Never Died       Riley Green   2019-09-20
# 6                             We Back      Jason Aldean   2019-11-22
# 7              What She Wants Tonight        Luke Bryan   2019-10-24
# 8                     Make Me Want To      Jimmie Allen   2018-10-12
# 12        I Hope (feat. Charlie Puth)     Gabby Barrett   2020-06-19
# ...                               ...               ...          ...
# 52477                  Southern Voice        Tim McGraw   2010-11-30
# 52483                       The Truth      Jason Aldean   2009-04-07
# 52486                Consider Me Gone     Reba McEntire   2009-01-01
# 52488  I Don't Want This Night To End        Luke Bryan   2011-08-09
# 52492                 Cowboy Casanova  Carrie Underwood         2009
#
#        popularity  acousticness  danceability  energy  instrumentalness  \
# ...

# %%
country.loc[country['genres'].str.contains('country'), 'genres'] = 'country'
country
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                  song            artist release_date  \
# 4          I Wish Grandpas Never Died       Riley Green   2019-09-20
# 6                             We Back      Jason Aldean   2019-11-22
# 7              What She Wants Tonight        Luke Bryan   2019-10-24
# 8                     Make Me Want To      Jimmie Allen   2018-10-12
# 12        I Hope (feat. Charlie Puth)     Gabby Barrett   2020-06-19
# ...                               ...               ...          ...
# ...

# %%
latin = data[data['genres'].str.contains("latin", na=False)]
latin
# Out:
#                                      song     artist release_date  popularity  \
# 37                                   Vete  Bad Bunny   2019-11-21        78.0
# 46                                   Easy  DaniLeigh   2019-05-31        72.0
# 136                                  Vete  Bad Bunny   2019-11-21        78.0
# 148                                  Easy  DaniLeigh   2019-05-31        72.0
# 244                                  Vete  Bad Bunny   2019-11-21        78.0
# ...                                   ...        ...          ...         ...
# 52287  Give It up to Me (feat. Lil Wayne)    Shakira         2009        46.0
# 52344           Shut It Down (feat. Akon)    Pitbull   2009-08-31        48.0
# 52391  Give It up to Me (feat. Lil Wayne)    Shakira         2009        46.0
# 52407           Shut It Down (feat. Akon)    Pitbull   2009-08-31        48.0
# 52491  Give It up to Me (feat. Lil Wayne)    Shakira         2009        46.0
#
# ...

# %%
latin.loc[latin['genres'].str.contains('latin'), 'genres'] = 'latin'
latin
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                      song     artist release_date  popularity  \
# 37                                   Vete  Bad Bunny   2019-11-21        78.0
# 46                                   Easy  DaniLeigh   2019-05-31        72.0
# 136                                  Vete  Bad Bunny   2019-11-21        78.0
# 148                                  Easy  DaniLeigh   2019-05-31        72.0
# 244                                  Vete  Bad Bunny   2019-11-21        78.0
# ...                                   ...        ...          ...         ...
# ...

# %%
kpop = data[data['genres'].str.contains("k-pop","korean pop", na=False)]
kpop
# Out:
#                                       song               artist release_date  \
# 1222            Make It Right (feat. Lauv)                  BTS   2019-10-18
# 1545   Chicken Noodle Soup (feat. Becky G)               j-hope   2019-09-27
# 2683           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# 3237           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# 3348           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# ...                                    ...                  ...          ...
# 40054                         Little Talks  Of Monsters and Men   2012-01-01
# 40152                         Little Talks  Of Monsters and Men   2012-01-01
# 40257                         Little Talks  Of Monsters and Men   2012-01-01
# 40360                         Little Talks  Of Monsters and Men   2012-01-01
# 40449                         Little Talks  Of Monsters and Men   2012-01-01
#
# ...

# %%
kpop.loc[kpop['genres'].str.contains('k-pop','korean pop'), 'genres'] = 'k-pop'
kpop
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                       song               artist release_date  \
# 1222            Make It Right (feat. Lauv)                  BTS   2019-10-18
# 1545   Chicken Noodle Soup (feat. Becky G)               j-hope   2019-09-27
# 2683           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# 3237           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# 3348           Boy With Luv (feat. Halsey)                  BTS   2019-04-12
# ...                                    ...                  ...          ...
# ...

# %%
dance = data[data['genres'].str.contains("dance", na=False)]
dance
# Out:
#                                        song           artist release_date  \
# 1                 RITMO (Bad Boys For Life)  Black Eyed Peas   2019-10-12
# 5                                     Slide           H.E.R.   2019-09-27
# 17                       Heat (feat. Gunna)      Chris Brown   2019-06-28
# 18                                Graveyard           Halsey   2020-01-17
# 22               Say So (feat. Nicki Minaj)         Doja Cat   2020-05-01
# ...                                     ...              ...          ...
# 52493                           It Kills Me    Melanie Fiona   2009-01-01
# 52495                      Hey, Soul Sister            Train   2010-12-01
# 52498             Tie Me Down (feat. Ray J)         New Boyz   2009-09-15
# 52499  Evacuate The Dancefloor - Radio Edit          Cascada         2009
# 52501              Say Aah (feat. Fabolous)       Trey Songz   2009-08-31
#
#        popularity  acousticness  danceability  energy  instrumentalness  \
# ...

# %%
dance.loc[dance['genres'].str.contains('dance'), 'genres'] = 'dance'
dance
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                                        song           artist release_date  \
# 1                 RITMO (Bad Boys For Life)  Black Eyed Peas   2019-10-12
# 5                                     Slide           H.E.R.   2019-09-27
# 17                       Heat (feat. Gunna)      Chris Brown   2019-06-28
# 18                                Graveyard           Halsey   2020-01-17
# 22               Say So (feat. Nicki Minaj)         Doja Cat   2020-05-01
# ...                                     ...              ...          ...
# ...

# %%
rock = data[data['genres'].str.contains("rock", na=False)]
rock
# Out:
#                        song          artist release_date  popularity  \
# 27             Ridin’ Roads    Dustin Lynch   2020-01-17        68.0
# 47       Remember You Young    Thomas Rhett   2019-05-31        62.0
# 70                 Memories        Maroon 5   2021-06-11        84.0
# 80     Heartache Medication       Jon Pardi   2019-09-27        66.0
# 85                   Sucker  Jonas Brothers   2019-06-07        81.0
# ...                     ...             ...          ...         ...
# 52467          Use Somebody   Kings of Leon   2008-09-23        76.0
# 52473             Fireflies        Owl City   2009-01-01        79.0
# 52486      Consider Me Gone   Reba McEntire   2009-01-01        55.0
# 52487       Fallin' For You  Colbie Caillat         2009        59.0
# 52495      Hey, Soul Sister           Train   2010-12-01        82.0
#
#        acousticness  danceability  energy  instrumentalness  liveness  \
# ...

# %%
rock.loc[rock['genres'].str.contains('rock'), 'genres'] = 'rock'
rock
# Out:
# /Users/jessicaveilleux/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#                        song          artist release_date  popularity  \
# 27             Ridin’ Roads    Dustin Lynch   2020-01-17        68.0
# 47       Remember You Young    Thomas Rhett   2019-05-31        62.0
# 70                 Memories        Maroon 5   2021-06-11        84.0
# 80     Heartache Medication       Jon Pardi   2019-09-27        66.0
# 85                   Sucker  Jonas Brothers   2019-06-07        81.0
# ...                     ...             ...          ...         ...
# ...

# %%
# # Connect to Postgres
# db_string = f'postgresql://{user_info}@{connection_string}'
# engine = create_engine(db_string)

# %%
# # Send to Postgres
# cleaned_genre_songs.to_sql('popular_songs', con = engine, if_exists = 'append', index = False, chunksize=5200)
