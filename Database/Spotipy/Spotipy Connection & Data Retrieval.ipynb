# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
from sqlalchemy import create_engine
import backoff

# %%
from config import SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET, user_info, connection_string

# %%
#Set up Spotify credentials
client_credentials_manager = SpotifyClientCredentials(SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Set up genre csv
genres_df = pd.read_csv("../../Cleaning Codes/genre_artist.csv")
genres_df.head()
# Out:
#                        id  followers                genres  \
# 0  0VLMVnVbJyJ4oyZs2L3Yl2       71.0        carnaval cadiz
# 1  0dt23bs4w8zx154C5xdVyl       63.0        carnaval cadiz
# 2  0pGhoB99qpEJEsBQxgaskQ       64.0        carnaval cadiz
# 3  3HDrX2OtSuXLW5dLR85uN3       53.0        carnaval cadiz
# 4  22mLrN5fkppmuUPsHx6i2G       59.0  classical harp, harp
#
#                            name  popularity
# 0  Las Viudas De Los Bisabuelos           6
# 1             Los De Capuchinos           5
# 2            Los “Pofesionales”           7
# 3     Los Que No Paran De Rajar           6
# 4                   Vera Dulova           3

# %%
# rename columns for later join
genres_df.drop(columns = ['id', 'followers', 'popularity'], inplace = True)
genres_df.rename(columns = {'name':'artist'}, inplace = True)

# %%
#Set up Hot 100 csv
hot100 = pd.read_csv('charts.csv')

# Any empty Hot 100 cells?
hot100.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         31971
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
# Clean DataFrame
hot100 = hot100.drop(columns = ['last-week', 'peak-rank'])
hot100.head()
# Out:
#          date  rank                 song  \
# 0  2021-06-12     1               Butter
# 1  2021-06-12     2             Good 4 U
# 2  2021-06-12     3           Levitating
# 3  2021-06-12     4  Leave The Door Open
# 4  2021-06-12     5      Save Your Tears
#
#                                      artist  weeks-on-board
# 0                                       BTS               2
# 1                            Olivia Rodrigo               3
# 2                 Dua Lipa Featuring DaBaby              35
# 3  Silk Sonic (Bruno Mars & Anderson .Paak)              13
# 4                The Weeknd & Ariana Grande              25

# %%
hot100.dtypes
# Out:
# date              object
# rank               int64
# song              object
# artist            object
# weeks-on-board     int64
# dtype: object

# %%
# Transform date into a date-time value
hot100["date"] = pd.to_datetime(hot100["date"])
hot100.dtypes
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# weeks-on-board             int64
# dtype: object

# %%
# Sort by date
hot100 = hot100.sort_values(by = 'date', ascending = False)
hot100.head()
# Out:
#          date  rank         song                 artist  weeks-on-board
# 0  2021-06-12     1       Butter                    BTS               2
# 64 2021-06-12    65        amari                J. Cole               3
# 75 2021-06-12    76  What's Next                  Drake              13
# 73 2021-06-12    74    4 Da Gang  42 Dugg & Roddy Ricch               9
# 72 2021-06-12    73    Quicksand                 Morray              17

# %%
# Get the desired timeframe
selecthot100 = hot100.loc[(hot100['date'] >= '2010-01-01') & (hot100['date'] <='2020-01-31')]

# %%
def getTrackFeatures(song_id):
    #Query Spotify
    meta = sp.track(song_id)
    features = sp.audio_features(song_id)
    
    track= {
        # Meta data
        "song": meta['name'],
        "artist": meta['album']['artists'][0]['name'],
        "release_date": meta['album']['release_date'],
        "popularity": meta['popularity'],

        # features
        "acousticness": features[0]['acousticness'],
        "danceability": features[0]['danceability'],
        "energy": features[0]['energy'],
        "instrumentalness": features[0]['instrumentalness'],
        "liveness": features[0]['liveness'],
        "loudness": features[0]['loudness'],
        "speechiness": features[0]['speechiness'],
        "tempo": features[0]['tempo']
    }
    
    return track

# %%
def searchSongs(title, artist):
    # Clean artist for Spotify query
    cleaned_artist = artist.replace(" Featuring", "")
    hot_song_features = {}
    
    # Query database, get top result and call getTrackFeatures to get audio features for track
    try:
        results = sp.search(q=f'track:{title} artist:{cleaned_artist}')
        top_result = results['tracks']['items'][0]
        hot_song_features = getTrackFeatures(top_result['id'])
    except:
        
        #If query fails, search without artist
        try:
            results = sp.search(q=f'track:{title}')
            top_result = results['tracks']['items'][0]
            hot_song_features = getTrackFeatures(top_result['id'])
        except:
            # Print songs that fail.
            print(f'Failed to find {title} by {artist}.')
    return hot_song_features

# %%
def getSongData(row):
    # API calls automatically rate limited by Spotipy
    song_details = searchSongs(row['song'], row['artist'])
    
    #Make dictionary based on data from searchSongs
    song_details['popular_date'] = row['date']
    song_details['ranking'] = row['rank']
    song_details['weeks_on_board'] = row['weeks-on-board']
    return song_details

# %%
# Get data from Spotify using custom functions
hot_song_features = [getSongData(song) for idx, song in selecthot100.iterrows()]
# Out:
# Failed to find Don't Check On Me by Chris Brown Featuring Justin Bieber & Ink.
# Failed to find Can't Leave Without It by 21 Savage.
# Failed to find Can't Leave Without It by 21 Savage.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Can't Leave Without It by 21 Savage.
# Failed to find Can't Leave Without It by 21 Savage.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find Wouldn't Leave by Kanye West Featuring PARTYNEXTDOOR.
# Failed to find Must've Never Met You by Luke Combs.
# Failed to find Wouldn't Leave by Kanye West Featuring PARTYNEXTDOOR.
# Failed to find Lost In Japan by Shawn Mendes X Zedd.
# Failed to find My Choppa Hate N****s by 21 Savage & Metro Boomin.
# Failed to find My Choppa Hate N****s by 21 Savage & Metro Boomin.
# Failed to find Don't Get Too High by Bryson Tiller.
# Failed to find Can't Have Everything by Drake.
# Failed to find Can't Have Everything by Drake.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find With You Tonight / Hasta El Amanecer by Nicky Jam.
# Failed to find Don't Hurt Yourself by Beyonce Featuring Jack White.
# Failed to find Don't Hurt Yourself by Beyonce Featuring Jack White.
# Failed to find I'm Not Gonna Miss You by Glen Campbell.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find You're Mine (Eternal) by Mariah Carey.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Raise A Man by K. Michelle.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Can't Remember To Forget You by Shakira Featuring Rihanna.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Don't Drop That Thun Thun! by The FiNATTiCZ.
# Failed to find Riff Off: Mickey / Like A Virgin / Hit Me With Your Best Shot... by The Barden Bellas, The Treblemakers & The BU Harmonics.
# Failed to find Riff Off: Mickey / Like A Virgin / Hit Me With Your Best Shot... by The Barden Bellas, The Treblemakers & The BU Harmonics.
# Failed to find Riff Off: Mickey / Like A Virgin / Hit Me With Your Best Shot... by The Barden Bellas, The Treblemakers & The BU Harmonics.
# Failed to find Riff Off: Mickey / Like A Virgin / Hit Me With Your Best Shot... by The Barden Bellas, The Treblemakers & The BU Harmonics.
# Failed to find Riff Off: Mickey / Like A Virgin / Hit Me With Your Best Shot... by The Barden Bellas, The Treblemakers & The BU Harmonics.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find Don't Stop (Color On The Walls) by Foster The People.
# Failed to find I'm Not Gonna Teach Your Boyfriend To Dance With You by Glee Cast.
# Failed to find Don't Cry For Me Argentina (Lea Michele Version) by Glee Cast.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Give Me A Sign (Forever And Ever) by Breaking Benjamin.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Give Me A Sign (Forever And Ever) by Breaking Benjamin.
# Failed to find Give Me A Sign (Forever And Ever) by Breaking Benjamin.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Give Me A Sign (Forever And Ever) by Breaking Benjamin.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Give Me A Sign (Forever And Ever) by Breaking Benjamin.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Ain't Back Yet by Kenny Chesney.
# Failed to find Didn't You Know How Much I Loved You by Kellie Pickler.
# Failed to find Didn't You Know How Much I Loved You by Kellie Pickler.
# Failed to find Stranded (Haiti Mon Amour) by Jay-Z, Bono, The Edge & Rihanna.
# Failed to find Stranded (Haiti Mon Amour) by Jay-Z, Bono, The Edge & Rihanna.

# %%
# Make DataFrame with Spotify data
cleaned_hot_songs = pd.DataFrame(data = hot_song_features)
cleaned_hot_songs
# Out:
#                                                     song           artist  \
# 0      Take What You Want (feat. Ozzy Osbourne & Trav...      Post Malone
# 1                              RITMO (Bad Boys For Life)  Black Eyed Peas
# 2                      BEST ON EARTH (feat. BIA) - Bonus             Russ
# 3                                                   Tusa  Various Artists
# 4                             I Wish Grandpas Never Died      Riley Green
# ...                                                  ...              ...
# 52595               Evacuate The Dancefloor - Radio Edit          Cascada
# 52596                              Live Like We're Dying       Kris Allen
# 52597                           Say Aah (feat. Fabolous)       Trey Songz
# 52598                                        Gangsta Luv       Snoop Dogg
# 52599                                         Baby By Me          50 Cent
#
#       release_date  popularity  acousticness  danceability  energy  \
# 0       2019-09-06        76.0       0.09060         0.499   0.800
# 1       2019-10-12        78.0       0.03340         0.721   0.716
# 2       2020-01-31        71.0       0.18800         0.846   0.748
# 3       2019-12-20        45.0       0.29500         0.803   0.715
# 4       2019-09-20        71.0       0.03600         0.445   0.492
# ...            ...         ...           ...           ...     ...
# 52595         2009        60.0       0.01950         0.760   0.696
# 52596   2009-11-16        52.0       0.02730         0.589   0.893
# 52597   2009-08-31        63.0       0.00453         0.724   0.870
# 52598   2009-01-01        53.0       0.02770         0.590   0.735
# 52599   2009-01-01        58.0       0.00450         0.611   0.827
#
#        instrumentalness  liveness  loudness  speechiness    tempo  \
# 0              0.000000    0.1470    -2.665       0.0502  139.919
# 1              0.000840    0.2370    -7.037       0.0657  104.994
# 2              0.000000    0.0930    -3.512       0.0780   90.006
# 3              0.000134    0.0574    -3.280       0.2980  101.085
# 4              0.000000    0.1220    -5.717       0.0294  148.013
# ...                 ...       ...       ...          ...      ...
# 52595          0.000000    0.2780    -5.811       0.0491  127.029
# 52596          0.000000    0.3430    -2.948       0.0397   92.011
# 52597          0.000000    0.8330    -3.614       0.1130   93.010
# 52598          0.000000    0.0818    -4.924       0.2970  102.076
# 52599          0.013200    0.0283    -4.665       0.0876  190.058
#
#       popular_date  ranking  weeks_on_board
# 0       2020-01-25       70              19
# 1       2020-01-25       67               8
# 2       2020-01-25       68               6
# 3       2020-01-25       69               7
# 4       2020-01-25       75               3
# ...            ...      ...             ...
# 52595   2010-01-02       28              19
# 52596   2010-01-02       33               8
# 52597   2010-01-02       34               6
# 52598   2010-01-02       35               9
# 52599   2010-01-02       36               8
#
# [52600 rows x 15 columns]

# %%
# add in genre
genre_songs = pd.merge(cleaned_hot_songs, genres_df, how = 'left', on = ['artist'])
genre_songs
# Out:
#                                                     song           artist  \
# 0      Take What You Want (feat. Ozzy Osbourne & Trav...      Post Malone
# 1                              RITMO (Bad Boys For Life)  Black Eyed Peas
# 2                      BEST ON EARTH (feat. BIA) - Bonus             Russ
# 3                      BEST ON EARTH (feat. BIA) - Bonus             Russ
# 4                                                   Tusa  Various Artists
# ...                                                  ...              ...
# 53078               Evacuate The Dancefloor - Radio Edit          Cascada
# 53079                              Live Like We're Dying       Kris Allen
# 53080                           Say Aah (feat. Fabolous)       Trey Songz
# 53081                                        Gangsta Luv       Snoop Dogg
# 53082                                         Baby By Me          50 Cent
#
#       release_date  popularity  acousticness  danceability  energy  \
# 0       2019-09-06        76.0       0.09060         0.499   0.800
# 1       2019-10-12        78.0       0.03340         0.721   0.716
# 2       2020-01-31        71.0       0.18800         0.846   0.748
# 3       2020-01-31        71.0       0.18800         0.846   0.748
# 4       2019-12-20        45.0       0.29500         0.803   0.715
# ...            ...         ...           ...           ...     ...
# 53078         2009        60.0       0.01950         0.760   0.696
# 53079   2009-11-16        52.0       0.02730         0.589   0.893
# 53080   2009-08-31        63.0       0.00453         0.724   0.870
# 53081   2009-01-01        53.0       0.02770         0.590   0.735
# 53082   2009-01-01        58.0       0.00450         0.611   0.827
#
#        instrumentalness  liveness  loudness  speechiness    tempo  \
# 0              0.000000    0.1470    -2.665       0.0502  139.919
# 1              0.000840    0.2370    -7.037       0.0657  104.994
# 2              0.000000    0.0930    -3.512       0.0780   90.006
# 3              0.000000    0.0930    -3.512       0.0780   90.006
# 4              0.000134    0.0574    -3.280       0.2980  101.085
# ...                 ...       ...       ...          ...      ...
# 53078          0.000000    0.2780    -5.811       0.0491  127.029
# 53079          0.000000    0.3430    -2.948       0.0397   92.011
# 53080          0.000000    0.8330    -3.614       0.1130   93.010
# 53081          0.000000    0.0818    -4.924       0.2970  102.076
# 53082          0.013200    0.0283    -4.665       0.0876  190.058
#
#       popular_date  ranking  weeks_on_board  \
# 0       2020-01-25       70              19
# 1       2020-01-25       67               8
# 2       2020-01-25       68               6
# 3       2020-01-25       68               6
# 4       2020-01-25       69               7
# ...            ...      ...             ...
# 53078   2010-01-02       28              19
# 53079   2010-01-02       33               8
# 53080   2010-01-02       34               6
# 53081   2010-01-02       35               9
# 53082   2010-01-02       36               8
#
#                                                   genres
# 0                              dfw rap, melodic rap, rap
# 1                                dance pop, pop, pop rap
# 2                         hawaiian hip hop, pop rap, rap
# 3                                               uk drill
# 4                                                    NaN
# ...                                                  ...
# 53078  bubblegum dance, dance pop, eurodance, europop...
# 53079  acoustic pop, idol, indiecoustica, neo mellow,...
# 53080  dance pop, pop, post-teen pop, r&b, trap, urba...
# 53081  g funk, gangster rap, hip hop, pop rap, rap, w...
# 53082  east coast hip hop, gangster rap, hip hop, pop...
#
# [53083 rows x 16 columns]

# %%
# Make sure data fits Postgres Primary Key requirements
cleaned_genre_songs = genre_songs.drop_duplicates(subset = ['song', 'popular_date'])
cleaned_genre_songs =
# Out:
#                                                  song           artist  \
# 0   Take What You Want (feat. Ozzy Osbourne & Trav...      Post Malone
# 1                           RITMO (Bad Boys For Life)  Black Eyed Peas
# 2                   BEST ON EARTH (feat. BIA) - Bonus             Russ
# 4                                                Tusa  Various Artists
# 5                          I Wish Grandpas Never Died      Riley Green
# ..                                                ...              ...
# 67                                       Dance Monkey      Tones And I
# 68                  10,000 Hours (with Justin Bieber)       Dan + Shay
# 69                                  Someone You Loved    Lewis Capaldi
# 70                                Lose You To Love Me     Selena Gomez
# 71                                           Memories         Maroon 5
#
#    release_date  popularity  acousticness  danceability  energy  \
# 0    2019-09-06        76.0        0.0906         0.499   0.800
# 1    2019-10-12        78.0        0.0334         0.721   0.716
# 2    2020-01-31        71.0        0.1880         0.846   0.748
# 4    2019-12-20        45.0        0.2950         0.803   0.715
# 5    2019-09-20        71.0        0.0360         0.445   0.492
# ..          ...         ...           ...           ...     ...
# 67   2019-10-17        84.0        0.6920         0.824   0.588
# 68   2019-10-04        83.0        0.1530         0.654   0.630
# 69   2019-05-17        87.0        0.7510         0.501   0.405
# 70   2020-01-10        81.0        0.5560         0.488   0.343
# 71   2021-06-11        84.0        0.8410         0.775   0.327
#
#     instrumentalness  liveness  loudness  speechiness    tempo popular_date  \
# 0           0.000000    0.1470    -2.665       0.0502  139.919   2020-01-25
# 1           0.000840    0.2370    -7.037       0.0657  104.994   2020-01-25
# 2           0.000000    0.0930    -3.512       0.0780   90.006   2020-01-25
# 4           0.000134    0.0574    -3.280       0.2980  101.085   2020-01-25
# 5           0.000000    0.1220    -5.717       0.0294  148.013   2020-01-25
# ..               ...       ...       ...          ...      ...          ...
# 67          0.000104    0.1490    -6.400       0.0924   98.027   2020-01-25
# 68          0.000000    0.1110    -4.644       0.0259   89.991   2020-01-25
# 69          0.000000    0.1050    -5.679       0.0319  109.891   2020-01-25
# 70          0.000000    0.2100    -8.985       0.0436  102.819   2020-01-25
# 71          0.000000    0.0821    -7.241       0.0557   91.050   2020-01-25
#
#     ranking  weeks_on_board                              genres
# 0        70              19           dfw rap, melodic rap, rap
# 1        67               8             dance pop, pop, pop rap
# 2        68               6      hawaiian hip hop, pop rap, rap
# 4        69               7                                 NaN
# 5        75               3  contemporary country, country road
# ..      ...             ...                                 ...
# 67        8              15                 australian pop, pop
# 68        7              15  contemporary country, country, pop
# 69        6              36                         pop, uk pop
# 70        5              13       dance pop, pop, post-teen pop
# 71        4              17                       pop, pop rock
#
# [71 rows x 16 columns]

# %%
# Connect to Postgres
db_string = f'postgresql://{user_info}@{connection_string}'
engine = create_engine(db_string)

# %%
# Send to Postgres
cleaned_genre_songs.to_sql('popular_songs', con = engine, if_exists = 'append', index = False, chunksize=5200)
